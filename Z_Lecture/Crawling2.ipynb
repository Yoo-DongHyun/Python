# %%
url = 'https://search.naver.com/search.naver'
params = { 
    'where' : 'news',
    'query' : '펭수'      
}

# %%
import requests

# %%
resp = requests.get(url,params)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="펭수 : 네이버 뉴스검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'펭수\'의 네이버 뉴스검색 결과입니다."> <meta name="description" lang="ko" content="\'펭수\'의 네이버 뉴스검색 결과입니다."> <title>펭수 : 네이버 뉴스검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_200109.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.text
# Out:
# '          펭수 : 네이버 뉴스검색     if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) 
# ...

# %%
li_tags = soup.find_all('li')


# news_list=[]

# for news in peng_news_titles:
#     title = news.text
#     link = news.get('href')
#     news_list.append({
#         'title' : title,
#         'link' : link
#     })
# news_list

# %%
ul_tag = soup.find('ul',class_ = 'type01')

# %%
ul_tag
# Out:
# <ul class="type01"> <li id="sp_nws1"> <div class="thumb"><a class="sp_thmb thmb80" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank"><img alt="LG생건, 펭수 손잡고 " class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2020%2F01%2F21%2F9665108.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank" title="LG생건, 펭수 손잡고 착한 섬유 유연제 알린다">LG생건, <strong class="hl">펭수</st
# ...

# %%
li_tags = ul_tag.find_all('li', recursive=False)

# %%
len(li_tags)
# Out:
# 10

# %%
li_tags
# Out:
# [<li id="sp_nws1"> <div class="thumb"><a class="sp_thmb thmb80" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank"><img alt="LG생건, 펭수 손잡고 " class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2020%2F01%2F21%2F9665108.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank" title="LG생건, 펭수 손잡고 착한 섬유 유연제 알린다">LG생건, <strong class="hl">펭수</strong> 손잡고 착한 섬유 유연제
# ...

# %%
li_tags
# Out:
# [<li id="sp_nws1"> <div class="thumb"><a class="sp_thmb thmb80" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank"><img alt="LG생건, 펭수 손잡고 " class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2020%2F01%2F21%2F9665108.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a></div> <dl> <dt><a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank" title="LG생건, 펭수 손잡고 착한 섬유 유연제 알린다">LG생건, <strong class="hl">펭수</strong> 손잡고 착한 섬유 유연제
# ...

# %%
a_tags = ul_tag.find_all('a',class_='_sp_each_title')

# %%
a_tags
# Out:
# [<a class="_sp_each_title" href="http://www.newsis.com/view/?id=NISX20200121_0000895784&amp;cID=13001&amp;pID=13000" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000127_000000000000000009665108&amp;g=003.0009665108&amp;u='+urlencode(this.href));" target="_blank" title="LG생건, 펭수 손잡고 착한 섬유 유연제 알린다">LG생건, <strong class="hl">펭수</strong> 손잡고 착한 섬유 유연제 알린다</a>,
#  <a class="_sp_each_title" href="http://www.fnnews.com/news/202001210913104825" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=6&amp;i=880000FF_000000000000000004360643&amp;g=014.0004360643&amp;u='+urlencode(this.href));" target="_blank" title="LG생건 샤프란 아우라, 대세 '펭수' 모델로 발탁">LG생건 샤프란 아우라, 대세 '<strong class="hl">펭수</strong>' 모델로 발탁</a>,
# ...

# %%
leng(ul_tag
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7cb283449a73> in <module>
# ----> 1 leng(ul_tag
#       2 )
#
# NameError: name 'leng' is not defined

# %%
len(li_tags)
# Out:
# 10

# %%
len(li_tags)
# Out:
# 10

# %%
#원하는 키워드 받아, 기사 제목, 링크 가져오고 그 링크의 바디까지 가져오기

# keyword = input("무엇을 검색할래요?")

# url = 'https://search.naver.com/search.naver'
# params = { 
#     'where' : 'news',
#     'query' : '%s'% keyword      
# }
# resp = requests.get(url,params)
# soup = BeautifulSoup(resp.content)
# ul_tag = soup.find('ul',class_ = 'type01')
# li_tags = soup.find_all('li')

link_list = []
br_tag_list = []
final_list=[]

for li_tag in li_tags:
    a_tag = li_tag.find('a', class_='_sp_each_title')
    title= a_tag.text
    link = a_tag.get('href')
    link_list.append(link) 
    
for link_each in link_list: 
    link_resp= requests.get(link_each)
    link_soup= BeautifulSoup(link_resp.content)
    body_tag =link_soup.find('body')
    final_list.append({
            'title' : title,
            'link' : link,
            'link_body' : body_tag
        })
    
final_list
# Out:
# [{'title': '스파오 x 펭수, 2차 협업 상품도 주문 폭주',
#   'link': 'http://www.fashionbiz.co.kr/TN/?cate=2&recom=2&idx=176279',
#   'link_body': <body id="newsis"><!--<![endif]-->
#   <div id="wrap" style="height: auto;">
#   <a class="skip" href="#container">본문영역 바로가기</a>
#   <div id="header">
#   <div class="hd_rellink">
#   <div class="bxcn1">
#   <div class="lgroup">
#   <span class="date"></span>
#   <span class="weather">
#   </span>
#   <div class="cboth"></div>
#   </div>
#   <div class="rgroup">
#   <ul class="sitelink lgroup">
#   <li><a class="c1" href="http://k-artprice.newsis.com" target="_blank"><strong>K-Artprice</strong></a></li>
#   <li><a class="c1" href="/msi"><strong>MSI</strong></a></li>
#   <li><a class="c1" href="http://prime.newsis.com" target="_blank"><strong>프라임뉴스</strong></a></li>
#   <li><a class="c1" href="http://weekly.newsis.com" target="_blank"><strong>위클리</strong></a></li>
#   <li><a href="/m_service/web/">모바일</a></li>
#   </ul>
#   <ul class="sociallink lgroup">
# ...

# %%
url = 'https://search.naver.com/search.naver'
params = {
    'where' : 'news',
    'query': '오늘+날씨'
}

resp = requests.get(url, params=params)

soup = BeautifulSoup(resp.content)
ul_tag = soup.find('ul', class_='type01')
news_li_tag= ul_tag.find_all('li', recursive=False)

my_news_list=[]
for each_news in news_li_tag:
    a_tag = each_news.find('a', class_='_sp_each_title')
    title = a_tag.text
    linnk = a_tag.get('href')
    desc = each_news.find_all('dd')[1].text
    
    my_news_list.append({
        'title' : title,
        'link' : link,
        'desc' : desc
    })

for idx, my_news in enumerate(my_news_list):
    resp = requests.get(my_news.get('link'))
    soup = BeautifulSoup(resp.content)
    
    my_news_list[idx]['content'] = soup.find('body')

# %%
my_news_list
# Out:
# [{'title': '[날씨] 충청이남 비·눈, 내일 전국 확대…큰 추위 없어',
#   'link': 'http://www.fashionbiz.co.kr/TN/?cate=2&recom=2&idx=176279',
#   'desc': '설 연휴를 앞두고 눈, 비 소식이 있습니다. 오늘은 충청도와 남부지방을 중심으로 내리겠고, 내일은 전국으로 확대될 텐데요. 자세한 날씨는 기상캐스터 연결해 알아보겠습니다. 구본아 캐스터. [캐스터] 네, 보통 설 연휴...',
#   'content': <body leftmargin="0" ondragstart="return true" onload="AutoSourcing.init('article_%id%');all_blur();" onselectstart="return true" topmargin="0">
#   <script type="text/javascript">
#   <!--
#   //============================================================================
#   // 이미지 자동 리사이즈
#   //============================================================================
#    function imgResize()
#    {
#        // DivContents 영역에서 이미지가 maxsize 보다 크면 자동 리사이즈 시켜줌
#        maxsize = 650; // 가로사이즈 ( 다른값으로 지정하면됨)
#        var content = document.getElementById("article_1");
#        var img = content.getElementsByTagName("img");
#        for(i=0; i<img.length; i++)
#        {
#
# ...
